# %%
#line chart
import matplotlib.pyplot as plt
import numpy
#one axis
a=range(1,16)
#other axis random numbers with mean and sigma
mean =50
sigma=10
b = numpy.random.normal(mean, sigma, 15).astype(int)
# The numpy library's random.normal function is used to generate random numbers that follow a normal (or Gaussian) distribution.
# The syntax of the function is as follows:
# numpy.random.normal(loc=0.0, scale=1.0, size=None)
# loc : Mean (“centre”) of the distribution.
# scale : Standard deviation (spread or “width”) of the distribution.
# size : Output shape. If the given shape is, e.g., (m, n, k), then m * n * k samples are drawn.
# The function generates random numbers from a normal distribution,
# with the mean and standard deviation specified by the user. 
# In the above code,size is 15, so it will return 15 random numbers with mean 50 and standard deviation 10.
#need to change to int since out put of numpy function is numpy array in float.

plt.plot(a,b)

# %%
import pandas

sales_in_Delhi = [34,45,33,45,49]
sales_in_Pune = [12,13,6,14,10]
sales_in_Mumbai = [67,78,90,75,85]
sales = pandas.DataFrame({'Delhi':sales_in_Delhi,'Pune':sales_in_Pune,'Mumbai':sales_in_Mumbai})
print(sales)
colors=['Red','Green','Blue']
sales.plot(xticks=range(1,5),yticks=range(0,100,20), color=colors, kind='bar')
# Out:
#    Delhi  Pune  Mumbai
# 0     34    12      67
# 1     45    13      78
# 2     33     6      90
# 3     45    14      75
# 4     49    10      85
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

cities=['patna','Bangalore','Delhi']
cars=[200,345,789]
plt.bar(cities,cars)
# Out:
# <BarContainer object of 3 artists>

# %%
import matplotlib.pyplot as plt

cities=['patna','Bangalore','Delhi']
cars=[200,345,789]
plt.pie(cars,labels=cities,colors=['Red','Blue','Green'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1cd35ee7ac0>,
# ...
#  [Text(0.9802247553581336, 0.49915872123312366, 'patna'),
#   Text(-0.2009260051408454, 1.0814937542390808, 'Bangalore'),
#   Text(-0.31171313588691374, -1.0549099112794167, 'Delhi')])

# %%
import numpy
import matplotlib.pyplot as plt
mean = 20
sigma = 5
hist_data = numpy.random.normal(mean, sigma, 500).astype(int)

plt.hist(hist_data)
# Out:
# (array([  6.,  18.,  45., 113.,  97., 112.,  80.,  20.,   7.,   2.]),
#  array([ 4. ,  7.3, 10.6, 13.9, 17.2, 20.5, 23.8, 27.1, 30.4, 33.7, 37. ]),
#  <BarContainer object of 10 artists>)

# %%
import numpy
import matplotlib.pyplot as plt

scatter_1=numpy.sort(numpy.random.normal(20,5,50)).astype(int)
scatter_2=numpy.sort(numpy.random.normal(20,5,50)).astype(int)
plt.scatter(scatter_1,scatter_2)

# %%
import numpy
import matplotlib.pyplot as plt

scatter_1=numpy.sort(numpy.random.normal(20,5,50)).astype(int)
scatter_2=numpy.sort(numpy.random.normal(20,5,50)).astype(int)
plt.boxplot(scatter_2)
plt.boxplot(scatter_1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2669eedefd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2669eee95b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2669eeded00>],
#  'medians': [<matplotlib.lines.Line2D at 0x2669eee9b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2669eee9e20>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
import pandas
import numpy

# plottng OOO way
#On one axis number from 1 to 15
a = range (1,16)

#On other axis generate random integers with mean and sigma
mean = 50
sigma = 10
b = numpy.random.normal(mean, sigma, 15).astype(int)

#First, we define figure object
figure_object = plt.figure()

#Add axes
axes = figure_object.add_axes([.1,.1,1,1])

#Adding grid
axes.grid()

#Set axes labels
axes.set_xlabel('X')
axes.set_ylabel('Y')

#Set axes ticks
axes.set_xticks(range(1,15))
axes.set_yticks(range(20,100,10))

#Set axes limit
axes.set_xlim([1,15])
axes.set_ylim([20,80])

#Generating plot
axes.plot(a,b)

# %%
import matplotlib.pyplot as plt
import pandas
import numpy

a = range (1,16)

b = numpy.random.normal(50, 10, 15).astype(int)

mean = 20
sigma = 5
c = numpy.random.normal(mean, sigma, 15).astype(int)

#Create figure object
fig_sub_object = plt.figure()

#Two axes inside figure object.
number_of_rows= 1
number_of_cols = 2
fig_sub_object, (axes1,axes2) = plt.subplots(number_of_rows,number_of_cols)

axes1.plot(a,b)
axes2.plot(a,c)

# %%
import seaborn

#Generate random integers with mean and sigma
mean = 25
sigma = 10
dist_data_1 = numpy.random.normal (mean, sigma,500).astype(int)
dist_data_2 = numpy.random.normal(mean+5, sigma-4,500).astype(int)
dist_data_3 = numpy.random.normal(mean-5, sigma+2,500).astype(int)
dist_data = pandas.DataFrame({"A":dist_data_1,"B":dist_data_2,"C":dist_data_3})

#First we need to create categorical data
data = ["Delhi", "Pune", "Ajmer"]

#This code will create categorical data of 500 length with
# some predefined probability of each class.
dist_data['city'] = numpy.random.choice(data, 500, p=[0.5,0.2, 0.3]).tolist()

#Create class variable
dist_data['gender'] = numpy.random.choice(['Male','Female'],500, p=[0.6, 0.4]).tolist()
seaborn.distplot(dist_data_1,bins=10)
# Out:
# C:\Users\vivek.kishore\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
import numpy
import seaborn
import pandas
data_1=numpy.random.normal(25,10,500).astype(int)
data_2=numpy.random.normal(20,15,500).astype(int)
data_3=numpy.random.normal(30,5,500).astype(int)
data_df=pandas.DataFrame({'A':data_1,'B':data_2,'C':data_3})
city_nm=['Patna','Mumbai','Delhi']
gender_nm=['Male','Female']
data_df['city']=numpy.random.choice(city_nm,500,p=[0.5,0.2,0.3]).tolist()
data_df['gender']=numpy.random.choice(gender_nm,500,p=[0.6,0.4]).tolist()

seaborn.jointplot(x=data_1,y=data_2, kind="kde")
seaborn.jointplot(x=data_1,y=data_2)

# %%
import numpy
import seaborn
import pandas
data_1=numpy.random.normal(25,10,500).astype(int)
data_2=numpy.random.normal(20,15,500).astype(int)
data_3=numpy.random.normal(30,5,500).astype(int)
data_df=pandas.DataFrame({'A':data_1,'B':data_2,'C':data_3})
city_nm=['Patna','Mumbai','Delhi']
gender_nm=['Male','Female']
data_df['city']=numpy.random.choice(city_nm,500,p=[0.5,0.2,0.3]).tolist()
data_df['gender']=numpy.random.choice(gender_nm,500,p=[0.6,0.4]).tolist()

seaborn.pairplot(data_df)

# %%
import numpy
import seaborn
import pandas
data_1=numpy.random.normal(25,10,500).astype(int)
data_2=numpy.random.normal(20,15,500).astype(int)
data_3=numpy.random.normal(30,5,500).astype(int)
data_df=pandas.DataFrame({'A':data_1,'B':data_2,'C':data_3})
city_nm=['Patna','Mumbai','Delhi']
gender_nm=['Male','Female']
data_df['city']=numpy.random.choice(city_nm,500,p=[0.5,0.2,0.3]).tolist()
data_df['gender']=numpy.random.choice(gender_nm,500,p=[0.6,0.4]).tolist()
# seaborn.stripplot(x='city',y='B',data=data_df,jitter=True)
seaborn.violinplot(x='B',y='gender',data=data_df)
# Out:
# <AxesSubplot:xlabel='B', ylabel='gender'>

# %%
import numpy
import seaborn
import pandas
data_1=numpy.random.normal(25,10,500).astype(int)
data_2=numpy.random.normal(20,15,500).astype(int)
data_3=numpy.random.normal(30,5,500).astype(int)
data_df=pandas.DataFrame({'A':data_1,'B':data_2,'C':data_3})
city_nm=['Patna','Mumbai','Delhi']
gender_nm=['Male','Female']
data_df['city']=numpy.random.choice(city_nm,500,p=[0.5,0.2,0.3]).tolist()
data_df['gender']=numpy.random.choice(gender_nm,500,p=[0.6,0.4]).tolist()

seaborn.pointplot (x="B", y="city", hue='gender',data=data_df)
# Out:
# <AxesSubplot:xlabel='B', ylabel='city'>

# %%
import numpy
import seaborn
import pandas
data_1=numpy.random.normal(25,10,500).astype(int)
data_2=numpy.random.normal(20,15,500).astype(int)
data_3=numpy.random.normal(30,5,500).astype(int)
data_df=pandas.DataFrame({'A':data_1,'B':data_2,'C':data_3})
city_nm=['Patna','Mumbai','Delhi']
gender_nm=['Male','Female']
data_df['city']=numpy.random.choice(city_nm,500,p=[0.5,0.2,0.3]).tolist()
data_df['gender']=numpy.random.choice(gender_nm,500,p=[0.6,0.4]).tolist()
seaborn.stripplot(x='city',y='B',data=data_df,jitter=True)
# Out:
# <AxesSubplot:xlabel='city', ylabel='B'>
