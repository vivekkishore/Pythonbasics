# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekkishore/Pythonbasics/blob/main/pjrank2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.kernel_ridge import KernelRidge

# %%
pjrankdf1=pd.read_excel('pjrank2.xlsx')
pjrankdf1.head()
# Out:
#                          meeting details                          Job profile  \
# 0  people lead connect - discuss queries     Packaged App Development Analyst
# 1  people lead connect - discuss queries           Business Interlock Manager
# 2         User login issue - client call  custom software engineering analyst
# 3     troubleshooting call - login issue  custom software engineering analyst
# 4     troubleshooting call - login issue            Tech Architecture Manager
#
#                                           Job family  \
# 0                  Human Resources > Talent Strategy
# 1        Training & Development > Business Interlock
# 2  Software Engineering > Custom Software Enginee...
# 3  Software Engineering > Custom Software Enginee...
# 4  Software Engineering > Custom Software Enginee...
#
#    Overall experience(in years)                         Primary Skill  \
# 0                      0.821429                     Microsoft ASP.NET
# 1                      0.428571                     Automated Testing
# 2                      0.571429                   Behavioral Sciences
# 3                      0.285714                     .NET Architecture
# 4                      0.357143  Advance Front End Development NodeJs
#
#                     secondary Skill certifications  Org Experience  TQ score  \
# 0  Avanade Scrum Project Management          Scrum        0.611111  0.000000
# 1                 Vendor Management          Azure        0.944444  1.000000
# 2              Agile Team Practices          Azure        0.388889  0.888889
# 3          Jakarta Enterprise Beans    management         0.722222  1.000000
# 4                           Angular          Azure        0.777778  0.888889
#
#   Language proficiency  ...  Management level     Specialization  \
# 0      english, german  ...          0.166667              Azure
# 1     english, chinese  ...          0.666667              Azure
# 2    english, japanese  ...          0.000000              Azure
# 3       english, hindi  ...          0.000000                SAP
# 4      english, french  ...          0.000000  Microsoft backend
#
#       Trainings Highest qualification countrycode Meeting required/optional  \
# 0         Azure                   mca          IN                         1
# 1  google cloud                   mca          PH                         0
# 2          Java                   mca          PH                         1
# 3           SAP                   bca          IN                         0
# 4       angular                   mba          IN                         0
#
#    Email mention(yes/No)  meeting type(series/instance)  \
# 0                      1                              0
# 1                      0                              1
# 2                      0                              1
# 3                      0                              0
# 4                      1                              1
#
#    recent emails related to meeting invite(yes/No)  rank_score
# 0                                                1    0.389648
# 1                                                1    0.230539
# 2                                                1    0.611211
# 3                                                1    0.457625
# 4                                                0    0.358788
#
# [5 rows x 21 columns]
